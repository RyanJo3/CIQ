# %%
from pathlib import Path

# %%
folder_path = Path('D:\\DX LV2')

# %%
files = list(folder_path.glob('*.xlsx'))

# %%
for file in files :
    print(file)
# Out:
# D:\DX LV2\ciq.xlsx
# D:\DX LV2\CIQDASHBOARD.xlsx

# %%
import pandas as pd

# %%
df = pd.read_excel("D:\\DX LV2\\CIQDASHBOARD.xlsx")

# %%
df.to_csv("dashboard.csv")

# %%
df2 = pd.read_csv("dashboard.csv")

# %%
df2
# Out:
#       Unnamed: 0 발생월   주차            구분         E:P              모델명  \
# 0              0  1월  1주차   240102최형철01     068.멀티V   RPUW18BX9M.AKM
# 1              1  1월  1주차   240102한영범01     068.멀티V  GPUW251C2SM.AKM
# 2              2  1월  1주차   240102윤재영01  071.상업용스탠드  PNW1453T9FR.AKM
# 3              3  1월  1주차   230102최세진01     068.멀티V   RPUW14GX9E.AKM
# 4              4  1월  1주차   240102한영범02     068.멀티V   RPUW14BX9P.AKM
# ...          ...  ..  ...           ...         ...              ...
# 1296        1296  8월  5주차   240830김두섭01  038.상업용스탠드  PNW2900F9SF.AKM
# 1297        1297  8월  5주차   240830석재봉01     035.멀티V   RNW0520A2U.AKM
# 1298        1298  8월  5주차  240731이재동01      035.멀티V   RNW0600A2U.AKM
# 1299        1299  8월  5주차   240830김정진01  036.카세트/덕트  UUW145039FR.AKM
# 1300        1300  8월  5주차   240830이재동02     035.멀티V   RPUW241X9H.AKM
#
#              일련번호                                                 제목  \
# ...

# %%
df2.to_excel("ciqdashboard.xlsx")

# %%
savd_xlsx =pd.ExcelWriter("ciqdash.xlsx")

# %%
df2.to_excel(savd_xlsx, index = False)

# %%
savd_xlsx.save()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 savd_xlsx.save()
#
# AttributeError: 'OpenpyxlWriter' object has no attribute 'save'
